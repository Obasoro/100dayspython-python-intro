# %%
import numpy as np

np.random.seed(0)

def compute_reciprocal(values):
    output = np.empty(len(values))
    for i in range(len(values)):
        output[i] = 1.0 /values[1]
        
    return output

values = np.random.randint(1, 10, size=5)
compute_reciprocal(values)
# Out:
# array([1., 1., 1., 1., 1.])

# %%
from collections import namedtuple

# %%
metro_data = [('Tokyo', 'JP', 36,99, (35.689722, 139.691667)),
           ('Delhi NCR', 'IN', 21.935, (28.613889, 77.288889)),
           ('Mexico City', 'MX', 20.142, (19.4333333, -99.133333)),
           ('New York-Newark', 'US', 20.104, (40.808611, -74.020386)),
           ('Soa Paola', 'BR', 19.649, (-23.547778, -46.635833))
           ]

# %%
from operator import itemgetter
for city in sorted(metro_data, key=itemgetter(2)):
    print(city)
# Out:
# ('Soa Paola', 'BR', 19.649, (-23.547778, -46.635833))
# ('New York-Newark', 'US', 20.104, (40.808611, -74.020386))
# ('Mexico City', 'MX', 20.142, (19.4333333, -99.133333))
# ('Delhi NCR', 'IN', 21.935, (28.613889, 77.288889))
# ('Tokyo', 'JP', 36, 99, (35.689722, 139.691667))

# %%
Latlog = namedtuple('LatLong', 'Lat Long)
metropolis = namedtuple('Metropolis','name cc pop coord')
metro_area = [metropolis(name, cc, pop, Latlong(lat, Long))
for name, cc, pop, (Lat,Long) in metro_data]
# Out:
#   File "<ipython-input-5-068bfd357fb2>", line 1
#     Latlog = namedtuple('LatLong', 'Lat Long)
#                                              ^
# SyntaxError: EOL while scanning string literal

# %%
cc_name = itemgetter(1, 0)
for city in metro_data:
    print(cc_name)

# %%
import operator
from operator import attrgetter
[name for name in dir(operator) if not name.startswith(' ')]

# %%
from operator import methodcaller
kunle = 'A life in God'
upcase = methodcaller('upper')
upcase(kunle)

# %%
kunle.upper()

# %%
from abc import ABC, abstractmethod
from collections import namedtuple

# %%
Customer = namedtuple('Customer', 'name fidelity')

class LineItem:
    def__init__(self, product, quantity, price):
        self.product = product
        self.quantity = quantity
        self.price = price
        
    def total(self):
        return self.price * self.quantity
    
    
class Order:
    
    def__init__(self, customer, cart, promtion=None):
        self.customer = customer
        self.cart = cart
        self.promotion = promotion
        
    def total(self):
        if not hasattr(self, ' __total'):
            self.__total = sum(item.total() for item in self.cart)
            
        return self.__total
    
    def due(self):
        if self.promotion is None:
            discount = 0
        else:
            discount = self.promotion.discount(self)
        return self.total() * discount

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
# %matplotlib inline
import cv2

# %%
Geo_image = cv2.imread("C:\\Users\\Toyin Obasoro\\Desktop\\Aero-EM.png", 1)

# %%
cv2.imshow('Original', Geo_image)

# %%
plt.figure(figsize=(10,10))
plt.imshow(Geo_image)

# %%
gray_image = cv2.cvtColor(Geo_image, cv2.COLOR_BGR2GRAY)

# %%
blur_image = cv2.GaussianBlur(gray_image, (3,3),0)

# %%
Thresh_image = cv2.adaptiveThreshold(blur_image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 205, 1)

# %%
plt.figure(figsize=(10,10))
plt.imshow(Thresh_image)

# %%
_, contours = cv2.findContours(Thresh_image, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

# %%
print(len(contours))
# Out:
# 1

# %%
"""filtered = []
for c in contours:
    if cv2.contourArea(c) < 1: continue
    filtered.append(c)
print(len(filtered))"""
# Out:
# 'filtered = []\nfor c in contours:\n    if cv2.contourArea(c) < 1: continue\n    filtered.append(c)\nprint(len(filtered))'

# %%
#object_image = np.zero([image.shape[0], image.shape[1], 3], 'unit8')

# %%
for c in filtered:
    col = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    cv2.drawContours(object,[c], -1, col, -1)
    p = cv2.arcLength(c, True)
    print(area, p)
cv2.imshow('Contours', objects)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8217047e8d65> in <module>
#       4     p = cv2.arcLength(c, True)
#       5     print(area, p)
# ----> 6 cv2.imshow('Contours', objects)
#
# NameError: name 'objects' is not defined

# %%
image = cv2.imread("C:\\Users\\Toyin Obasoro\\Desktop\\Aero-EM.png",0)
edges = cv2.Canny(image,100,200)
plt.figure(figsize=(20,20))
plt.subplot(121),plt.imshow(image,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
#plt.figure(figsize=(20,20))
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.imshow(gray_image)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
def sweet(x):
    return (x*2)**2
    
for n in range(5):
    print(sweet(n))
# Out:
# 0
# 4
# 16
# 36
# 64

# %%
print(map(sweet, range(5)))

# %%
print(list(map(sweet, range(5))))
# Out:
# [0, 4, 16, 36, 64]
