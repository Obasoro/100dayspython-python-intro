# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')
import datasist as ds

# %matplotlib inline

# %% [markdown]
# # Importing of Train, Test Data
#
# Pandas Module would be used in loading the data

# %%
train_data = pd.read_csv("C:\\Users\\Toyin Obasoro\\Downloads\\train_data.csv")
test_data = pd.read_csv("C:\\Users\\Toyin Obasoro\\Downloads\\test_data.csv")

# %%
train_data_copy = train_data.copy()
test_data_copy = test_data.copy()

# %% [markdown]
# # Data Exploratory for Loan Prediction

# %%
train_data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
test_data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
train_data.shape
# Out:
# (614, 13)

# %%
test_data.shape
# Out:
# (367, 12)

# %%
train_data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
ds.structdata.describe(train_data)
# Out:
# First five data points
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# ...

# %%
ds.structdata.check_train_test_set(train_data, test_data,'Loan_ID', 'Dependents')
# Out:
# There are 614 training rows and 367 test rows.
# There are 13 training columns and 12 test columns.
# Id field is unique.
# Train and test sets have distinct Ids.

# %%
train_data['Loan_Status'] = train_data['Loan_Status'].replace({"Y":1, "N":0})

# %%
ylabel = train_data.Loan_Status
train = train_data.drop(columns=['Loan_Status'])

all_data, ntrain, ntest = ds.structdata.join_train_and_test(train, test_data)

# %%
all_data.shape
# Out:
# (981, 12)

# %%
ds.structdata.display_missing(all_data)
# Out:
#              features  missing_counts  missing_percent
# 0             Loan_ID               0              0.0
# 1              Gender              24              2.4
# 2             Married               3              0.3
# 3          Dependents              25              2.5
# 4           Education               0              0.0
# 5       Self_Employed              55              5.6
# 6     ApplicantIncome               0              0.0
# 7   CoapplicantIncome               0              0.0
# 8          LoanAmount              27              2.8
# 9    Loan_Amount_Term              20              2.0
# 10     Credit_History              79              8.1
# 11      Property_Area               0              0.0

# %%
#fill categorical dataset
all_data = ds.feature_engineering.fill_missing_cats(all_data)
all_data = ds.feature_engineering.fill_missing_num(all_data)

# %%
ds.structdata.display_missing(all_data)
# Out:
#              features  missing_counts  missing_percent
# 0             Loan_ID               0              0.0
# 1              Gender               0              0.0
# 2             Married               0              0.0
# 3          Dependents               0              0.0
# 4           Education               0              0.0
# 5       Self_Employed               0              0.0
# 6     ApplicantIncome               0              0.0
# 7   CoapplicantIncome               0              0.0
# 8          LoanAmount               0              0.0
# 9    Loan_Amount_Term               0              0.0
# 10     Credit_History               0              0.0
# 11      Property_Area               0              0.0

# %%
ds.visualizations.histogram(all_data[:ntrain])

# %%
ds.visualizations.scatterplot(train_data, target='ApplicantIncome', separate_by='Loan_Status')

# %%
#drop Name and PassengerId
all_data['TotalIncome'] = all_data['ApplicantIncome'] + all_data['CoapplicantIncome'] 
all_data.drop(columns=['Loan_ID'], inplace=True)

# %%
label_enc = ['Dependents']

import category_encoders as ce

enc = ce.OrdinalEncoder()
all_data = enc.fit_transform(all_data)

# %%
all_data.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        1           1          1              1             5849
# 1       1        2           2          1              1             4583
# 2       1        2           1          1              2             3000
# 3       1        2           1          2              1             2583
# 4       1        1           1          1              1             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0   142.51153             360.0             1.0
# 1             1508.0   128.00000             360.0             1.0
# 2                0.0    66.00000             360.0             1.0
# 3             2358.0   120.00000             360.0             1.0
# 4                0.0   141.00000             360.0             1.0
#
#    Property_Area  TotalIncome
# 0              1       5849.0
# 1              2       6091.0
# ...

# %%
train = all_data[:ntrain]
test = all_data[ntrain:]

print(f"Shape of train {train.shape}")
print(f"Shape of test {test.shape}")
# Out:
# Shape of train (614, 12)
# Shape of test (367, 12)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
x_train,x_val,y_train,y_val=train_test_split(train,ylabel,test_size=0.3,random_state=101)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score

# %%
knn=KNeighborsClassifier(n_neighbors=15)
tree_gini=DecisionTreeClassifier(criterion="gini")
svm_lin=SVC(kernel="linear")
logr=LogisticRegression(C=100)
rf=RandomForestClassifier(max_depth=4, n_estimators=100)
models=[knn,tree_gini,svm_lin,logr,rf]

# %%
knn.fit(x_train,y_train)
knnpred=knn.predict(x_val)

# %%
tree_gini.fit(x_train,y_train)
tree_pred=tree_gini.predict(x_val)

# %%
svm_lin.fit(x_train,y_train)
svm_pred=tree_gini.predict(x_val)
logr.fit(x_train,y_train)
logpred=logr.predict(x_val)
rf.fit(x_train,y_train)
rfpred=rf.predict(x_val)

# %%
accuracysvm=accuracy_score(y_val,svm_pred)
f1scoresvm=f1_score(y_val,svm)
aucsvm=roc_auc_score=(y_val,svm_pred)
precisionsvm=precision_score(y_val,svm_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-03b88a848e39> in <module>
#       1 accuracysvm=accuracy_score(y_val,svm_pred)
# ----> 2 f1scoresvm=f1_score(y_val,svm)
#       3 aucsvm=roc_auc_score=(y_val,svm_pred)
#       4 precisionsvm=precision_score(y_val,svm_pred)
#
# NameError: name 'svm' is not defined

# %%
import pandas as pd
percentiles = df['arrival_delay_deciles'].apply(pd.Series)
percentiles = percentiles.rename(columns = lambda x : str(x*10) + "%")
df = pd.concat([df['departure_delay'], percentiles], axis=1)
df.head()
